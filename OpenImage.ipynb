# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread(r'imcolor4.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray',vmin=0,vmax=255)
plt.axis('off')
# Out:
# (-0.5, 529.5, 847.5, -0.5)
