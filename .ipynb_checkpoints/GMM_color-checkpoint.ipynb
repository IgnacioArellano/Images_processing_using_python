# %%
import numpy as np
from scipy import ndimage
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture
import cv2
from scipy.stats import multivariate_normal

# %%
def media(I):
    ch = I.shape[2]
    med=np.zeros(ch,)
    for i in range(ch):
        med[i]=np.mean(I[:,:,i].ravel())
    return med

# %%
def mcov(I):
    nx,ny,ch = I.shape
    It=np.zeros((ch,nx*ny))
    for i in range(ch):
        It[i,:]=I[:,:,i].ravel()
    cova=np.cov(It)
    return cova

# %%
I = cv2.imread('bote.jpg')
I = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)
plt.imshow(I,cmap='gray')
nx,ny,ch = I.shape

# %%
nm=2
phi=np.ones([nm,])/nm
med=np.zeros((nm,ch))
mc=np.zeros((nm,ch,ch))
for i in range(nm):
    roi=cv2.selectROI('sel',I)
    cv2.destroyWindow('sel')
    Iroi=I[int(roi[1]):int(roi[1]+roi[3]),int(roi[0]):int(roi[0]+roi[2]),:]
    med[i,:]=media(Iroi)
    mc[i,:,:]=mcov(Iroi)
# Out:
# [[134.37142857  16.47428571  18.02204082]
#  [111.0585835  139.30428447 162.24948994]]
# [[[193.54738562 203.07287582 199.73363679]
#   [203.07287582 466.29039216 443.85636788]
#   [199.73363679 443.85636788 425.05098439]]
#
#  [[ 19.64875356  -1.91549889 -10.56010131]
#   [ -1.91549889   5.22400205   6.47158382]
#   [-10.56010131   6.47158382  14.31616228]]]

# %%
lon=nx*ny
pdf=np.zeros((nm,lon))             
It=np.zeros((lon,ch))
for i in range(ch):
    It[:,i]=I[:,:,i].ravel()
It=It.astype(np.float)
pdf=np.zeros((lon,nm))   
for model in range(nm):
    pdf[:,model]=phi[model]*multivariate_normal.pdf(It[:,:], med[model,:] , mc[model,:,:])
pdft=np.sum(pdf,axis=1)
pdf=pdf.T
gamma=pdf/pdft
for model in range(nm):
    suma=np.sum(gamma[model,:])
    phi[model]=suma/lon
    med[model]=np.dot(gamma[model,:],Ir)/suma
    devstd[model]=np.sqrt(np.dot(gamma[model,:],(Ir-med[model])**2)/suma)
    f=normal_dist(x , med[model] , devstd[model]);
    f=f/np.sum(f)
    g=phi[model]*f
    gt=g+gt;
# Out:
# (2, 120000)

# %%
# Out:
#   File "<ipython-input-18-9e4cce3223fb>", line 2
#     It=np.zeros((ch,nx*ny))
#     ^
# SyntaxError: invalid syntax

# %%
nm=5
It=np.ravel(I)
It=np.reshape(It,(len(It),1))
classif = GaussianMixture(n_components=nm)
classif.fit(It)
w=classif.weights_
m=classif.means_
v=classif.covariances_
nx=np.zeros((256,nm))
x=np.arange(0,256,1)
for model in range(nm):
    for i in range(256):
        nx[i,model]=normpdf(i,m[model],np.sqrt(v[model]))
    nx[:,model]=w[model]*nx[:,model]
nt=np.sum(nx,axis=1)
fig1=plt.figure(figsize = (18,7))
plt.hist(I.ravel(),256,[0,256],density=True)
plt.plot(x,nx)
plt.plot(x,nt,'k--')
# plt.axvline(x=230,color='r')
plt.show()

# %%
np.random.seed(1)
n = 10
l = 256
im = np.zeros((l, l))
points = l*np.random.random((2, n**2))
im[(points[0]).astype(np.int), (points[1]).astype(np.int)] = 1
im = ndimage.gaussian_filter(im, sigma=l/(4.*n))

mask = (im > im.mean()).astype(np.float)


img = mask + 0.3*np.random.randn(*mask.shape)

print(img.shape)

# %%
hist, bin_edges = np.histogram(img, bins=60)
bin_centers = 0.5*(bin_edges[:-1] + bin_edges[1:])

classif = GaussianMixture(n_components=2)
classif.fit(img.reshape((img.size, 1)))

threshold = np.mean(classif.means_)
binary_img = img > threshold


plt.figure(figsize=(11,4))

plt.subplot(131)
plt.imshow(img)
plt.axis('off')
plt.subplot(132)
plt.plot(bin_centers, hist, lw=2)
plt.axvline(0.5, color='r', ls='--', lw=2)
plt.text(0.57, 0.8, 'histogram', fontsize=20, transform = plt.gca().transAxes)
plt.yticks([])
plt.subplot(133)
plt.imshow(binary_img, cmap=plt.cm.gray, interpolation='nearest')
plt.axis('off')

plt.subplots_adjust(wspace=0.02, hspace=0.3, top=1, bottom=0.1, left=0, right=1)
plt.show()
